# %%
import pandas as pd
import numpy as np

# %%
mydata = ["Boat", "Car","Bike", "Truck"]
myseries1 = pd.Series(mydata)

print(myseries1)
# Out:
# 0     Boat
# 1      Car
# 2     Bike
# 3    Truck
# dtype: object

# %%
mydata = [11, 22, 3, 1]
myseries2 = pd.Series(mydata)
print(myseries2)
# Out:
# 0    11
# 1    22
# 2     3
# 3     1
# dtype: int64
